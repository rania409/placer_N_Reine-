# %% [markdown]
# <html>
#     <body>
#         <h1 style="color:red;">Problème des n Reines</h1>
#     </body>
#     </html>

# %%
 #Python program for above approach
import math
ways = 0
print('donner le nombre de reine ');
n=int(input())
 
# Program to solve N-Queens Problem
def placerReine(board, row, rowmask, 
                              ldmask, rdmask):
   
    n = len(board)
     
    # All_rows_filled is a bit mask 
    # having all N bits set
    all_rows_filled = (1 << n) - 1
     
    # If rowmask will have all bits set, means
    # queen has been placed successfully
    # in all rows and board is diplayed
    if (rowmask == all_rows_filled):
        global ways
        ways = ways + 1
        print("=====================")
        print("solution numero " + (str)(ways))
        print("=====================")
        printBoard(board)
         
    # We extract a bit mask(safe) by rowmask,
    # ldmask and rdmask. all set bits of 'safe' 
    # indicates the safe column index for queen
    # placement of this iteration for row index(row).
    safe = all_rows_filled & (~(rowmask | 
                                   ldmask | rdmask))
     
    while (safe > 0):
       
        # Extracts the right-most set bit
        # (safe column index) where queen 
        # can be placed for this row
        p = safe & (-safe)
        col = (int)(math.log(p)/math.log(2))
        board[row][col] = 'R'
         
        # This is very important:
        # we need to update rowmask, ldmask and rdmask 
        # for next row as safe index for queen placement
        # will be decided by these three bit masks.
 
        # We have all three rowmask, ldmask and 
        # rdmask as 0 in beginning. Suppose, we are placing
        # queen at 1st column index at 0th row. rowmask, ldmask
        # and rdmask will change for next row as below:
  
        # rowmask's 1st bit will be set by OR operation
        # rowmask = 00000000000000000000000000000010
 
        # ldmask will change by setting 1st
        # bit by OR operation  and left shifting 
        # by 1 as it has to block the next column
        # of next row because that will fall on left diagonal.
        # ldmask = 00000000000000000000000000000100 
 
        # rdmask will change by setting 1st bit 
        # by OR operation and right shifting by 1
        # as it has to block the previous column
        # of next row because that will fall on right diagonal.
        # rdmask = 00000000000000000000000000000001
 
        # these bit masks will keep updated in each 
        # iteration for next row
        placerReine(board, row+1, rowmask|p, 
                           (ldmask|p) << 1, (rdmask|p) >> 1)
         
        # Reset right-most set bit to 0 so, next 
        # iteration will continue by placing the queen
        # at another safe column index of this row
        safe = safe & (safe-1)
         
        # Backtracking, replace 'R' by ' '
        board[row][col] = ' '
 
# Program to print board
def printBoard(board):
    for row in board:
        print("|" + "|".join(row) + "|")
 
# Driver Code        
def main():
   
   # n = 4;  # board size
    board = []
     
    for i in range (n):
        row = []
        for j in range (n):
            row.append(' ')
        board.append(row)
 
    rowmask = 0
    ldmask = 0
    rdmask = 0
    row = 0
     
    # Function Call
    placerReine(board, row, rowmask, ldmask, rdmask)
     
    # creates a new line
    print() 
    print("Nombre totale du solution pour placer " + (str)(n) +
                          " reines : " + (str)(ways))
     
if __name__== "__main__":
    main()
# Out:
# donner le nombre de reine
# 8
# =====================
# solution numero 1
# =====================
# |R| | | | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 2
# =====================
# |R| | | | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | |R| | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | |R| | | |
# =====================
# solution numero 3
# =====================
# |R| | | | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | |R| | | |
# | | |R| | | | | |
# =====================
# solution numero 4
# =====================
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 5
# =====================
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# =====================
# solution numero 6
# =====================
# | |R| | | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | | |R| | | | |
# =====================
# solution numero 7
# =====================
# | |R| | | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 8
# =====================
# | |R| | | | | | |
# | | | | | |R| | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# | | | | | | | |R|
# | | |R| | | | | |
# | | | | |R| | | |
# =====================
# solution numero 9
# =====================
# | |R| | | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | |R| | | | | |
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# =====================
# solution numero 10
# =====================
# | |R| | | | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | | | |R| | | |
# |R| | | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 11
# =====================
# | |R| | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 12
# =====================
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# | | | |R| | | | |
# =====================
# solution numero 13
# =====================
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | |R| | |
# =====================
# solution numero 14
# =====================
# | | |R| | | | | |
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# | | | | | |R| | |
# =====================
# solution numero 15
# =====================
# | | |R| | | | | |
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | | |R| | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# =====================
# solution numero 16
# =====================
# | | |R| | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# =====================
# solution numero 17
# =====================
# | | |R| | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | |R| | |
# =====================
# solution numero 18
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# =====================
# solution numero 19
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# =====================
# solution numero 20
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | |R| | | | |
# =====================
# solution numero 21
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | | | | | | |R| |
# | |R| | | | | | |
# =====================
# solution numero 22
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# =====================
# solution numero 23
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | |R| | | | | | |
# =====================
# solution numero 24
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 25
# =====================
# | | |R| | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# =====================
# solution numero 26
# =====================
# | | |R| | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | |R| | |
# =====================
# solution numero 27
# =====================
# | | |R| | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | |R| | | |
# =====================
# solution numero 28
# =====================
# | | |R| | | | | |
# | | | | | | | |R|
# | | | |R| | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | |R| | | |
# =====================
# solution numero 29
# =====================
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 30
# =====================
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# =====================
# solution numero 31
# =====================
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# | | | | | |R| | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | | |R| |
# =====================
# solution numero 32
# =====================
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | | |R| | | |
# =====================
# solution numero 33
# =====================
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | | | |R| | | |
# |R| | | | | | | |
# =====================
# solution numero 34
# =====================
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 35
# =====================
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 36
# =====================
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# =====================
# solution numero 37
# =====================
# | | | |R| | | | |
# | | | | | |R| | |
# |R| | | | | | | |
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | |R| | | | | |
# | | | | | | |R| |
# =====================
# solution numero 38
# =====================
# | | | |R| | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | |R| | | |
# =====================
# solution numero 39
# =====================
# | | | |R| | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | |R| | | | | | |
# =====================
# solution numero 40
# =====================
# | | | |R| | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 41
# =====================
# | | | |R| | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | |R| | | |
# |R| | | | | | | |
# | | | | | |R| | |
# =====================
# solution numero 42
# =====================
# | | | |R| | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | |R| | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | | | |R|
# =====================
# solution numero 43
# =====================
# | | | |R| | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# =====================
# solution numero 44
# =====================
# | | | |R| | | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# =====================
# solution numero 45
# =====================
# | | | |R| | | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 46
# =====================
# | | | |R| | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | |R| | |
# =====================
# solution numero 47
# =====================
# | | | | |R| | | |
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# =====================
# solution numero 48
# =====================
# | | | | |R| | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 49
# =====================
# | | | | |R| | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 50
# =====================
# | | | | |R| | | |
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# =====================
# solution numero 51
# =====================
# | | | | |R| | | |
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# |R| | | | | | | |
# =====================
# solution numero 52
# =====================
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | |R| | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# | | | | | | | |R|
# | | |R| | | | | |
# =====================
# solution numero 53
# =====================
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 54
# =====================
# | | | | |R| | | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | | |R| |
# =====================
# solution numero 55
# =====================
# | | | | |R| | | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | | |R| | | | |
# =====================
# solution numero 56
# =====================
# | | | | |R| | | |
# | | |R| | | | | |
# | | | | | | | |R|
# | | | |R| | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# =====================
# solution numero 57
# =====================
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | | |R| | | | |
# | |R| | | | | | |
# =====================
# solution numero 58
# =====================
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 59
# =====================
# | | | | |R| | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 60
# =====================
# | | | | |R| | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | | | |R|
# =====================
# solution numero 61
# =====================
# | | | | |R| | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | |R| | | | |
# =====================
# solution numero 62
# =====================
# | | | | |R| | | |
# | | | | | | |R| |
# | | | |R| | | | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | |R| | | | | | |
# =====================
# solution numero 63
# =====================
# | | | | |R| | | |
# | | | | | | | |R|
# | | | |R| | | | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | | | |R| |
# =====================
# solution numero 64
# =====================
# | | | | |R| | | |
# | | | | | | | |R|
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# =====================
# solution numero 65
# =====================
# | | | | | |R| | |
# |R| | | | | | | |
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | |R| | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# =====================
# solution numero 66
# =====================
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# | | | |R| | | | |
# =====================
# solution numero 67
# =====================
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | | |R| | | | | |
# =====================
# solution numero 68
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 69
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# =====================
# solution numero 70
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | | |R| |
# =====================
# solution numero 71
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# =====================
# solution numero 72
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | |R| |
# =====================
# solution numero 73
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | |R| | | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | | | |R| | | |
# =====================
# solution numero 74
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# |R| | | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 75
# =====================
# | | | | | |R| | |
# | | |R| | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | |R| | | |
# =====================
# solution numero 76
# =====================
# | | | | | |R| | |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | | | |R| |
# | | |R| | | | | |
# =====================
# solution numero 77
# =====================
# | | | | | |R| | |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# =====================
# solution numero 78
# =====================
# | | | | | |R| | |
# | | | |R| | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | |R| | | |
# | |R| | | | | | |
# | | | | | | | |R|
# =====================
# solution numero 79
# =====================
# | | | | | |R| | |
# | | | |R| | | | |
# | | | | | | |R| |
# |R| | | | | | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | |R| | | |
# | | |R| | | | | |
# =====================
# solution numero 80
# =====================
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | | |R| | | | | |
# =====================
# solution numero 81
# =====================
# | | | | | | |R| |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | |R| | | |
# =====================
# solution numero 82
# =====================
# | | | | | | |R| |
# | |R| | | | | | |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 83
# =====================
# | | | | | | |R| |
# | |R| | | | | | |
# | | | | | |R| | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | |R| | | | |
# | | | | | | | |R|
# | | | | |R| | | |
# =====================
# solution numero 84
# =====================
# | | | | | | |R| |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | | | | |R| | | |
# | |R| | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 85
# =====================
# | | | | | | |R| |
# | | |R| | | | | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | |R| | | |
# |R| | | | | | | |
# | | | | | |R| | |
# | | | |R| | | | |
# =====================
# solution numero 86
# =====================
# | | | | | | |R| |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | |R| | | |
# | | | | | | | |R|
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 87
# =====================
# | | | | | | |R| |
# | | | |R| | | | |
# | |R| | | | | | |
# | | | | | | | |R|
# | | | | | |R| | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | |R| | | |
# =====================
# solution numero 88
# =====================
# | | | | | | |R| |
# | | | | |R| | | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | |R| | |
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# =====================
# solution numero 89
# =====================
# | | | | | | | |R|
# | |R| | | | | | |
# | | | |R| | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
# | | |R| | | | | |
# | | | | | |R| | |
# =====================
# solution numero 90
# =====================
# | | | | | | | |R|
# | |R| | | | | | |
# | | | | |R| | | |
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | | |R| |
# | | | |R| | | | |
# | | | | | |R| | |
# =====================
# solution numero 91
# =====================
# | | | | | | | |R|
# | | |R| | | | | |
# |R| | | | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | |R| | | |
# | | | | | | |R| |
# | | | |R| | | | |
# =====================
# solution numero 92
# =====================
# | | | | | | | |R|
# | | | |R| | | | |
# |R| | | | | | | |
# | | |R| | | | | |
# | | | | | |R| | |
# | |R| | | | | | |
# | | | | | | |R| |
# | | | | |R| | | |
#
# Nombre totale du solution pour placer 8 reines : 92
